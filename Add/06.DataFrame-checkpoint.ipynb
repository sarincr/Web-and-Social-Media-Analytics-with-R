# %%
x <- read.csv(file = 'Sample - Superstore.csv')

# %%
x
# Out:
#      Row.ID Order.ID       Order.Date Ship.Date  Ship.Mode      Customer.ID
# 1     1     CA-2016-152156 08/11/2016 11/11/2016 Second Class   CG-12520
# 2     2     CA-2016-152156 08/11/2016 11/11/2016 Second Class   CG-12520
# 3     3     CA-2016-138688 12/06/2016 16/06/2016 Second Class   DV-13045
# 4     4     US-2015-108966 11/10/2015 18/10/2015 Standard Class SO-20335
# 5     5     US-2015-108966 11/10/2015 18/10/2015 Standard Class SO-20335
# 6     6     CA-2014-115812 09/06/2014 14/06/2014 Standard Class BH-11710
# 7     7     CA-2014-115812 09/06/2014 14/06/2014 Standard Class BH-11710
# 8     8     CA-2014-115812 09/06/2014 14/06/2014 Standard Class BH-11710
# 9     9     CA-2014-115812 09/06/2014 14/06/2014 Standard Class BH-11710
# 10   10     CA-2014-115812 09/06/2014 14/06/2014 Standard Class BH-11710
# 11   11     CA-2014-115812 09/06/2014 14/06/2014 Standard Class BH-11710
# 12   12     CA-2014-115812 09/06/2014 14/06/2014 Standard Class BH-11710
# ...

# %%
colnames(x)
# Out:
#  [1] "Row.ID"        "Order.ID"      "Order.Date"    "Ship.Date"
#  [5] "Ship.Mode"     "Customer.ID"   "Customer.Name" "Segment"
#  [9] "Country"       "City"          "State"         "Postal.Code"
# [13] "Region"        "Product.ID"    "Category"      "Sub.Category"
# [17] "Product.Name"  "Sales"         "Quantity"      "Discount"
# [21] "Profit"

# %%
is.data.frame(x)
# Out:
# [1] TRUE

# %%
ncol(x)
# Out:
# [1] 21

# %%
nrow(x)
# Out:
# [1] 9994

# %%
x$Category
# Out:
#    [1] "Furniture"       "Furniture"       "Office Supplies" "Furniture"
#    [5] "Office Supplies" "Furniture"       "Office Supplies" "Technology"
#    [9] "Office Supplies" "Office Supplies" "Furniture"       "Technology"
#   [13] "Office Supplies" "Office Supplies" "Office Supplies" "Office Supplies"
#   [17] "Office Supplies" "Office Supplies" "Office Supplies" "Technology"
#   [21] "Office Supplies" "Office Supplies" "Office Supplies" "Furniture"
#   [25] "Furniture"       "Office Supplies" "Technology"      "Furniture"
#   [29] "Office Supplies" "Furniture"       "Office Supplies" "Office Supplies"
#   [33] "Office Supplies" "Office Supplies" "Office Supplies" "Technology"
#   [37] "Furniture"       "Office Supplies" "Furniture"       "Furniture"
#   [41] "Technology"      "Technology"      "Office Supplies" "Office Supplies"
#   [45] "Technology"      "Office Supplies" "Office Supplies" "Technology"
#   [49] "Technology"      "Office Supplies" "Office Supplies" "Furniture"
# ...

# %%
x$Ship.Mode
# Out:
#    [1] "Second Class"   "Second Class"   "Second Class"   "Standard Class"
#    [5] "Standard Class" "Standard Class" "Standard Class" "Standard Class"
#    [9] "Standard Class" "Standard Class" "Standard Class" "Standard Class"
#   [13] "Standard Class" "Standard Class" "Standard Class" "Standard Class"
#   [17] "Standard Class" "Second Class"   "Second Class"   "Second Class"
#   [21] "Second Class"   "Standard Class" "Standard Class" "Second Class"
#   [25] "Standard Class" "Second Class"   "Second Class"   "Standard Class"
#   [29] "Standard Class" "Standard Class" "Standard Class" "Standard Class"
#   [33] "Standard Class" "Standard Class" "Second Class"   "First Class"
#   [37] "First Class"    "Standard Class" "Standard Class" "Standard Class"
#   [41] "Standard Class" "Standard Class" "Standard Class" "Standard Class"
#   [45] "First Class"    "First Class"    "Second Class"   "Standard Class"
#   [49] "Standard Class" "Standard Class" "Standard Class" "Standard Class"
# ...

# %%
max(x$Profit)
# Out:
# [1] 8399.976

# %%
min(x$Sales)
# Out:
# [1] 0.444

# %%
head(x)
# Out:
#   Row.ID Order.ID       Order.Date Ship.Date  Ship.Mode      Customer.ID
# 1 1      CA-2016-152156 08/11/2016 11/11/2016 Second Class   CG-12520
# 2 2      CA-2016-152156 08/11/2016 11/11/2016 Second Class   CG-12520
# 3 3      CA-2016-138688 12/06/2016 16/06/2016 Second Class   DV-13045
# 4 4      US-2015-108966 11/10/2015 18/10/2015 Standard Class SO-20335
# 5 5      US-2015-108966 11/10/2015 18/10/2015 Standard Class SO-20335
# 6 6      CA-2014-115812 09/06/2014 14/06/2014 Standard Class BH-11710
#   Customer.Name   Segment   Country       City            ⋯ Postal.Code Region
# 1 Claire Gute     Consumer  United States Henderson       ⋯ 42420       South
# 2 Claire Gute     Consumer  United States Henderson       ⋯ 42420       South
# 3 Darrin Van Huff Corporate United States Los Angeles     ⋯ 90036       West
# 4 Sean O'Donnell  Consumer  United States Fort Lauderdale ⋯ 33311       South
# 5 Sean O'Donnell  Consumer  United States Fort Lauderdale ⋯ 33311       South
# ...

# %%
tail(x)
# Out:
#      Row.ID Order.ID       Order.Date Ship.Date  Ship.Mode      Customer.ID
# 9989 9989   CA-2017-163629 17/11/2017 21/11/2017 Standard Class RA-19885
# 9990 9990   CA-2014-110422 21/01/2014 23/01/2014 Second Class   TB-21400
# 9991 9991   CA-2017-121258 26/02/2017 03/03/2017 Standard Class DB-13060
# 9992 9992   CA-2017-121258 26/02/2017 03/03/2017 Standard Class DB-13060
# 9993 9993   CA-2017-121258 26/02/2017 03/03/2017 Standard Class DB-13060
# 9994 9994   CA-2017-119914 04/05/2017 09/05/2017 Second Class   CC-12220
#      Customer.Name    Segment   Country       City        ⋯ Postal.Code Region
# 9989 Ruben Ausman     Corporate United States Athens      ⋯ 30605       South
# 9990 Tom Boeckenhauer Consumer  United States Miami       ⋯ 33180       South
# 9991 Dave Brooks      Consumer  United States Costa Mesa  ⋯ 92627       West
# 9992 Dave Brooks      Consumer  United States Costa Mesa  ⋯ 92627       West
# ...

# %%
sum(x$Sales)
# Out:
# [1] 2297201

# %%
sum(x$Sales)/(nrow(x))
# Out:
# [1] 229.858

# %%
mean(x$Sales)
# Out:
# [1] 229.858

# %%
median(x$Sales)
# Out:
# [1] 54.49

# %%
y=sort(x$Sales)

# %%
y
# Out:
#    [1]     0.4440     0.5560     0.8360     0.8520     0.8760     0.8980
#    [7]     0.9840     0.9900     1.0440     1.0800     1.0800     1.0800
#   [13]     1.1120     1.1670     1.1880     1.1880     1.1880     1.1920
#   [19]     1.2340     1.2400     1.2480     1.2480     1.2720     1.3440
#   [25]     1.3440     1.3440     1.3440     1.3620     1.3650     1.3920
#   [31]     1.4080     1.4080     1.4400     1.4480     1.4760     1.4760
#   [37]     1.5040     1.5240     1.5560     1.5840     1.5920     1.6240
#   [43]     1.6320     1.6400     1.6410     1.6800     1.6800     1.6960
#   [49]     1.7200     1.7280     1.7280     1.7280     1.7440     1.7520
#   [55]     1.7800     1.7880     1.7880     1.7880     1.8000     1.8100
#   [61]     1.8100     1.8240     1.8240     1.8690     1.8720     1.8720
#   [67]     1.8920     1.9080     1.9080     1.9280     1.9380     1.9410
#   [73]     1.9440     1.9640     1.9640     1.9800     1.9800     1.9840
# ...

# %%
sd(x$Sales)
# Out:
# [1] 623.2451

# %%
sqrt(x$Sales)
# Out:
#    [1]  16.1851784  27.0543897   3.8236109  30.9447492   4.7294820   6.9899928
#    [7]   2.6981475  30.1189641   4.3016276  10.7191418  41.3059802  30.1897996
#   [13]   3.9436024  20.1984158   8.2951793   1.5949922  25.8046507   7.4498322
#   [19]   2.9257478  14.6109548   4.7665501   4.4113490   7.7678826   8.4481951
#   [25]  32.3207364   3.4129166   9.5168272  55.5286413   3.1012901  11.1445054
#   [31]   1.8066544   9.2899946   2.6187783   3.9698866   5.4288120  33.1292016
#   [37]  13.8173804  10.6455625  23.0737773  14.5622114  19.2657209  12.1312819
#   [43]   8.8249646   9.7783434   6.7808554   4.1785165  14.5588461   6.7082039
#   [49]   4.6690470   6.1822326   8.6706401   2.4819347   9.4863059   3.9064050
#   [55]  32.0928341  14.4416066   5.6920998  17.8720452   3.8157568   5.4772256
#   [61]   6.9627581   1.2961481   3.7389838   5.0817320  12.1132159   8.9308454
#   [67]  14.5984588  33.3620143  12.9602469   8.7109127   2.1484878   4.3646306
# ...

# %%
length(x$Sales)
# Out:
# [1] 9994

# %%
corr<-(x$Sales-mean(x$Sales))/sd(x$Sales)

# %%
corr
# Out:
#    [1]  0.0515078244  0.8055931748 -0.3453504900  1.1676297151 -0.3329187837
#    [6] -0.2904122322 -0.3571275581  1.0867217386 -0.3391185918 -0.1844507093
#   [11]  2.3687727316  1.0935761847 -0.3438550911  0.2857912546 -0.2584023536
#   [16] -0.3647264947  0.6995995617 -0.2797583177 -0.3550737914 -0.0262785874
#   [21] -0.3323539979 -0.3375846848 -0.2719925126 -0.2542916113  1.3073059034
#   [26] -0.3501190794 -0.2234883206  4.5785710900 -0.3533762249 -0.1695288110
#   [31] -0.3635712509 -0.2303331397 -0.3578046593 -0.3435213540 -0.3215203788
#   [36]  1.3922066912 -0.0624762245 -0.1869729914  0.4854289250 -0.0285601938
#   [41]  0.2267326274 -0.1326765357 -0.2438494915 -0.2153919874 -0.2950332071
#   [46] -0.3407936952 -0.0287174353 -0.2966056222 -0.3338301427 -0.3074841674
#   [51] -0.2481816555 -0.3589246039 -0.2244189336 -0.3443236066  1.2837517672
#   [56] -0.0341727529 -0.3168223876  0.1436866477 -0.3454467603 -0.3206732001
# ...

# %%
which(x$Sales>mean(x$Sales))
# Out:
#    [1]    1    2    4    8   11   12   14   17   25   28   36   39   41   55
#   [15]   58   68   73   85   86  104  110  118  125  126  128  130  145  146
#   [29]  148  150  158  160  166  167  168  174  178  182  183  190  193  206
#   [43]  214  216  219  224  227  230  232  233  235  236  239  245  248  250
#   [57]  252  254  258  263  264  265  271  282  283  285  287  289  292  294
#   [71]  295  300  308  311  319  320  321  324  327  329  336  339  342  354
#   [85]  355  360  363  370  374  376  378  385  387  392  393  400  407  409
#   [99]  413  416  418  425  427  431  432  434  436  437  438  445  450  454
#  [113]  455  458  461  464  468  472  474  481  486  487  488  492  498  499
#  [127]  503  510  516  519  527  530  534  540  541  542  543  549  552  555
#  [141]  558  566  570  582  586  588  596  597  598  601  611  614  623  624
#  [155]  625  631  633  635  636  639  642  650  651  652  658  660  661  662
# ...

# %%
round(x$Sales)
# Out:
#    [1]   262   732    15   958    22    49     7   907    19   115  1706   911
#   [13]    16   408    69     3   666    56     9   213    23    19    60    71
#   [25]  1045    12    91  3083    10   124     3    86     7    16    29  1098
#   [37]   191   113   532   212   371   147    78    96    46    17   212    45
#   [49]    22    38    75     6    90    15  1030   209    32   319    15    30
#   [61]    48     2    14    26   147    80   213  1113   168    76     5    19
#   [73]   832    97    73     1    10    27    19   208    17    15    21   201
#   [85]   230   302    20     6   158    20    74     6    13    53    33     6
#   [97]    97    51    78    65    96     2    24   239   102    37    74    28
#  [109]     3   340    42    76    27    40     5    24   130   788   158    47
#  [121]    31   227   115    68   601   618     2   244    81   239    60    78
#  [133]    21    20    35    12     4    76    66    43    83     9    11   144
# ...

# %%
which(x$Sales>mean(x$Sales))
# Out:
#    [1]    1    2    4    8   11   12   14   17   25   28   36   39   41   55
#   [15]   58   68   73   85   86  104  110  118  125  126  128  130  145  146
#   [29]  148  150  158  160  166  167  168  174  178  182  183  190  193  206
#   [43]  214  216  219  224  227  230  232  233  235  236  239  245  248  250
#   [57]  252  254  258  263  264  265  271  282  283  285  287  289  292  294
#   [71]  295  300  308  311  319  320  321  324  327  329  336  339  342  354
#   [85]  355  360  363  370  374  376  378  385  387  392  393  400  407  409
#   [99]  413  416  418  425  427  431  432  434  436  437  438  445  450  454
#  [113]  455  458  461  464  468  472  474  481  486  487  488  492  498  499
#  [127]  503  510  516  519  527  530  534  540  541  542  543  549  552  555
#  [141]  558  566  570  582  586  588  596  597  598  601  611  614  623  624
#  [155]  625  631  633  635  636  639  642  650  651  652  658  660  661  662
# ...

# %%
y <- subset(x, Sales<mean(Sales))
y
# Out:
#      Row.ID Order.ID       Order.Date Ship.Date  Ship.Mode      Customer.ID
# 3     3     CA-2016-138688 12/06/2016 16/06/2016 Second Class   DV-13045
# 5     5     US-2015-108966 11/10/2015 18/10/2015 Standard Class SO-20335
# 6     6     CA-2014-115812 09/06/2014 14/06/2014 Standard Class BH-11710
# 7     7     CA-2014-115812 09/06/2014 14/06/2014 Standard Class BH-11710
# 9     9     CA-2014-115812 09/06/2014 14/06/2014 Standard Class BH-11710
# 10   10     CA-2014-115812 09/06/2014 14/06/2014 Standard Class BH-11710
# 13   13     CA-2017-114412 15/04/2017 20/04/2017 Standard Class AA-10480
# 15   15     US-2015-118983 22/11/2015 26/11/2015 Standard Class HP-14815
# 16   16     US-2015-118983 22/11/2015 26/11/2015 Standard Class HP-14815
# 18   18     CA-2014-167164 13/05/2014 15/05/2014 Second Class   AG-10270
# 19   19     CA-2014-143336 27/08/2014 01/09/2014 Second Class   ZD-21925
# 20   20     CA-2014-143336 27/08/2014 01/09/2014 Second Class   ZD-21925
# ...

# %%
nrow(y)
# Out:
# [1] 7634

# %%
y <- subset(x, Category == "Furniture")
y
# Out:
#      Row.ID Order.ID       Order.Date Ship.Date  Ship.Mode      Customer.ID
# 1      1    CA-2016-152156 08/11/2016 11/11/2016 Second Class   CG-12520
# 2      2    CA-2016-152156 08/11/2016 11/11/2016 Second Class   CG-12520
# 4      4    US-2015-108966 11/10/2015 18/10/2015 Standard Class SO-20335
# 6      6    CA-2014-115812 09/06/2014 14/06/2014 Standard Class BH-11710
# 11    11    CA-2014-115812 09/06/2014 14/06/2014 Standard Class BH-11710
# 24    24    US-2017-156909 16/07/2017 18/07/2017 Second Class   SF-20065
# 25    25    CA-2015-106320 25/09/2015 30/09/2015 Standard Class EB-13870
# 28    28    US-2015-150630 17/09/2015 21/09/2015 Standard Class TB-21520
# 30    30    US-2015-150630 17/09/2015 21/09/2015 Standard Class TB-21520
# 37    37    CA-2016-117590 08/12/2016 10/12/2016 First Class    GH-14485
# 39    39    CA-2015-117415 27/12/2015 31/12/2015 Standard Class SN-20710
# 40    40    CA-2015-117415 27/12/2015 31/12/2015 Standard Class SN-20710
# ...

# %%
y <- subset(x, Profit==max(Profit))
y
# Out:
#      Row.ID Order.ID       Order.Date Ship.Date  Ship.Mode      Customer.ID
# 6827 6827   CA-2016-118689 02/10/2016 09/10/2016 Standard Class TC-20980
#      Customer.Name Segment   Country       City      ⋯ Postal.Code Region
# 6827 Tamara Chand  Corporate United States Lafayette ⋯ 47905       Central
#      Product.ID      Category   Sub.Category
# 6827 TEC-CO-10004722 Technology Copiers
#      Product.Name                          Sales    Quantity Discount Profit
# 6827 Canon imageCLASS 2200 Advanced Copier 17499.95 5        0        8399.976

# %%
y <- subset(x, Category == "Technology" & Profit>5000)
y
# Out:
#      Row.ID Order.ID       Order.Date Ship.Date  Ship.Mode      Customer.ID
# 4191 4191   CA-2017-166709 17/11/2017 22/11/2017 Standard Class HL-15040
# 6827 6827   CA-2016-118689 02/10/2016 09/10/2016 Standard Class TC-20980
# 8154 8154   CA-2017-140151 23/03/2017 25/03/2017 First Class    RB-19360
#      Customer.Name Segment   Country       City      ⋯ Postal.Code Region
# 4191 Hunter Lopez  Consumer  United States Newark    ⋯ 19711       East
# 6827 Tamara Chand  Corporate United States Lafayette ⋯ 47905       Central
# 8154 Raymond Buch  Consumer  United States Seattle   ⋯ 98115       West
#      Product.ID      Category   Sub.Category
# 4191 TEC-CO-10004722 Technology Copiers
# 6827 TEC-CO-10004722 Technology Copiers
# 8154 TEC-CO-10004722 Technology Copiers
#      Product.Name                          Sales    Quantity Discount Profit
# 4191 Canon imageCLASS 2200 Advanced Copier 10499.97 3        0        5039.986
# ...

# %%
write.csv(x,"output.csv")
y <- read.csv("output.csv")
y
# Out:
#      X    Row.ID Order.ID       Order.Date Ship.Date  Ship.Mode
# 1     1    1     CA-2016-152156 08/11/2016 11/11/2016 Second Class
# 2     2    2     CA-2016-152156 08/11/2016 11/11/2016 Second Class
# 3     3    3     CA-2016-138688 12/06/2016 16/06/2016 Second Class
# 4     4    4     US-2015-108966 11/10/2015 18/10/2015 Standard Class
# 5     5    5     US-2015-108966 11/10/2015 18/10/2015 Standard Class
# 6     6    6     CA-2014-115812 09/06/2014 14/06/2014 Standard Class
# 7     7    7     CA-2014-115812 09/06/2014 14/06/2014 Standard Class
# 8     8    8     CA-2014-115812 09/06/2014 14/06/2014 Standard Class
# 9     9    9     CA-2014-115812 09/06/2014 14/06/2014 Standard Class
# 10   10   10     CA-2014-115812 09/06/2014 14/06/2014 Standard Class
# 11   11   11     CA-2014-115812 09/06/2014 14/06/2014 Standard Class
# 12   12   12     CA-2014-115812 09/06/2014 14/06/2014 Standard Class
# 13   13   13     CA-2017-114412 15/04/2017 20/04/2017 Standard Class
# ...

# %%
#install.packages("readxl")

# %%
 library("readxl")

# %%
x<-read_excel("Sample - Superstore.xlsx")
# Out:
# New names:
# • `` -> `...22`

# %%
x
# Out:
#      Row ID Order ID       Order Date Ship Date  Ship Mode      Customer ID
# 1     1     CA-2016-152156 08/11/2016 11/11/2016 Second Class   CG-12520
# 2     2     CA-2016-152156 08/11/2016 11/11/2016 Second Class   CG-12520
# 3     3     CA-2016-138688 12/06/2016 16/06/2016 Second Class   DV-13045
# 4     4     US-2015-108966 11/10/2015 18/10/2015 Standard Class SO-20335
# 5     5     US-2015-108966 11/10/2015 18/10/2015 Standard Class SO-20335
# 6     6     CA-2014-115812 09/06/2014 14/06/2014 Standard Class BH-11710
# 7     7     CA-2014-115812 09/06/2014 14/06/2014 Standard Class BH-11710
# 8     8     CA-2014-115812 09/06/2014 14/06/2014 Standard Class BH-11710
# 9     9     CA-2014-115812 09/06/2014 14/06/2014 Standard Class BH-11710
# 10   10     CA-2014-115812 09/06/2014 14/06/2014 Standard Class BH-11710
# 11   11     CA-2014-115812 09/06/2014 14/06/2014 Standard Class BH-11710
# 12   12     CA-2014-115812 09/06/2014 14/06/2014 Standard Class BH-11710
# ...

# %%
x$Profit
# Out:
#    [1]    41.9136   219.5820     6.8714  -383.0310     2.5164    14.1694
#    [7]     1.9656    90.7152     5.7825    34.4700    85.3092    68.3568
#   [13]     5.4432   132.5922  -123.8580    -3.8160    13.3176     9.9900
#   [19]     2.4824    16.0110     7.3840     5.0596    15.6884    -1.0196
#   [25]   240.2649     4.2224    11.7741 -1665.0522    -7.0532    15.5250
#   [31]     1.1016     9.7092    -5.7150     3.5460     9.9468   123.4737
#   [37]  -147.9630    35.4150   -46.9764   -15.1470    41.7564    16.5564
#   [43]     3.8940     9.5616    19.7714     8.2062     8.4784     4.9500
#   [49]     6.1040    17.9634    35.3346     2.9568    17.0981     6.2566
#   [55]   298.6855    52.1400    15.5520     7.0980     6.9888     3.3000
#   [61]    16.3620     0.8400     6.1512     9.3612    68.9631    22.3328
#   [67]   -15.2225   111.3024    62.9880    35.6636     1.7310     8.7630
#   [73]  -114.3912     1.2130   -18.1960    -1.9344    -5.8248     2.7240
# ...

# %%
max(x$Profit)
# Out:
# [1] 8399.976

# %%
y <- subset(x, Category == "Furniture")
y
# Out:
#      Row ID Order ID       Order Date Ship Date  Ship Mode      Customer ID
# 1      1    CA-2016-152156 08/11/2016 11/11/2016 Second Class   CG-12520
# 2      2    CA-2016-152156 08/11/2016 11/11/2016 Second Class   CG-12520
# 3      4    US-2015-108966 11/10/2015 18/10/2015 Standard Class SO-20335
# 4      6    CA-2014-115812 09/06/2014 14/06/2014 Standard Class BH-11710
# 5     11    CA-2014-115812 09/06/2014 14/06/2014 Standard Class BH-11710
# 6     24    US-2017-156909 16/07/2017 18/07/2017 Second Class   SF-20065
# 7     25    CA-2015-106320 25/09/2015 30/09/2015 Standard Class EB-13870
# 8     28    US-2015-150630 17/09/2015 21/09/2015 Standard Class TB-21520
# 9     30    US-2015-150630 17/09/2015 21/09/2015 Standard Class TB-21520
# 10    37    CA-2016-117590 08/12/2016 10/12/2016 First Class    GH-14485
# 11    39    CA-2015-117415 27/12/2015 31/12/2015 Standard Class SN-20710
# 12    40    CA-2015-117415 27/12/2015 31/12/2015 Standard Class SN-20710
# ...

# %%
x[1:3]
# Out:
#      Row ID Order ID       Order Date
# 1     1     CA-2016-152156 08/11/2016
# 2     2     CA-2016-152156 08/11/2016
# 3     3     CA-2016-138688 12/06/2016
# 4     4     US-2015-108966 11/10/2015
# 5     5     US-2015-108966 11/10/2015
# 6     6     CA-2014-115812 09/06/2014
# 7     7     CA-2014-115812 09/06/2014
# 8     8     CA-2014-115812 09/06/2014
# 9     9     CA-2014-115812 09/06/2014
# 10   10     CA-2014-115812 09/06/2014
# 11   11     CA-2014-115812 09/06/2014
# 12   12     CA-2014-115812 09/06/2014
# 13   13     CA-2017-114412 15/04/2017
# 14   14     CA-2016-161389 05/12/2016
# 15   15     US-2015-118983 22/11/2015
# 16   16     US-2015-118983 22/11/2015
# 17   17     CA-2014-105893 11/11/2014
# 18   18     CA-2014-167164 13/05/2014
# 19   19     CA-2014-143336 27/08/2014
# 20   20     CA-2014-143336 27/08/2014
# 21   21     CA-2014-143336 27/08/2014
# 22   22     CA-2016-137330 09/12/2016
# 23   23     CA-2016-137330 09/12/2016
# 24   24     US-2017-156909 16/07/2017
# ...

# %%
head(x)
# Out:
#   Row ID Order ID       Order Date Ship Date  Ship Mode      Customer ID
# 1 1      CA-2016-152156 08/11/2016 11/11/2016 Second Class   CG-12520
# 2 2      CA-2016-152156 08/11/2016 11/11/2016 Second Class   CG-12520
# 3 3      CA-2016-138688 12/06/2016 16/06/2016 Second Class   DV-13045
# 4 4      US-2015-108966 11/10/2015 18/10/2015 Standard Class SO-20335
# 5 5      US-2015-108966 11/10/2015 18/10/2015 Standard Class SO-20335
# 6 6      CA-2014-115812 09/06/2014 14/06/2014 Standard Class BH-11710
#   Customer Name   Segment   Country       City            ⋯ Region
# 1 Claire Gute     Consumer  United States Henderson       ⋯ South
# 2 Claire Gute     Consumer  United States Henderson       ⋯ South
# 3 Darrin Van Huff Corporate United States Los Angeles     ⋯ West
# 4 Sean O'Donnell  Consumer  United States Fort Lauderdale ⋯ South
# 5 Sean O'Donnell  Consumer  United States Fort Lauderdale ⋯ South
# 6 Brosina Hoffman Consumer  United States Los Angeles     ⋯ West
# ...

# %%
x[1,3]
# Out:
#   Order Date
# 1 08/11/2016

# %%
x[1,3]<-"08/11/2019"

# %%
x[1,3]
# Out:
#   Order Date
# 1 08/11/2019

# %%
head(x)
# Out:
#   Row ID Order ID       Order Date Ship Date  Ship Mode      Customer ID
# 1 1      CA-2016-152156 08/11/2019 11/11/2016 Second Class   CG-12520
# 2 2      CA-2016-152156 08/11/2016 11/11/2016 Second Class   CG-12520
# 3 3      CA-2016-138688 12/06/2016 16/06/2016 Second Class   DV-13045
# 4 4      US-2015-108966 11/10/2015 18/10/2015 Standard Class SO-20335
# 5 5      US-2015-108966 11/10/2015 18/10/2015 Standard Class SO-20335
# 6 6      CA-2014-115812 09/06/2014 14/06/2014 Standard Class BH-11710
#   Customer Name   Segment   Country       City            ⋯ Region
# 1 Claire Gute     Consumer  United States Henderson       ⋯ South
# 2 Claire Gute     Consumer  United States Henderson       ⋯ South
# 3 Darrin Van Huff Corporate United States Los Angeles     ⋯ West
# 4 Sean O'Donnell  Consumer  United States Fort Lauderdale ⋯ South
# 5 Sean O'Donnell  Consumer  United States Fort Lauderdale ⋯ South
# 6 Brosina Hoffman Consumer  United States Los Angeles     ⋯ West
# ...

# %%
x <- read.csv(file = 'Test.csv')

# %%
head(x)
# Out:
#   A B  C  D  E
# 1 1  1  2  3 Blue
# 2 2  4  6 10 Green
# 3 3  9 12 21 Blue
# 4 4 16 20 36 Red
# 5 5 25 30 55 Green
# 6 6 36 42 78 Blue

# %%
x$C <- ifelse(x$E == 'Blue', 'India', x$C)

# %%
x
# Out:
#    A  B   C     D   E
# 1   1   1 India   3 Blue
# 2   2   4 6      10 Green
# 3   3   9 India  21 Blue
# 4   4  16 20     36 Red
# 5   5  25 30     55 Green
# 6   6  36 India  78 Blue
# 7   7  49 56    105 Red
# 8   8  64 72    136 Red
# 9   9  81 India 171 Blue
# 10 10 100 110   210 Green
