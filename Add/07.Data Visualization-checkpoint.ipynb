# %%
x<-read.csv("Plot.csv")

# %%
x
# Out:
#    Days Sales Profit Discount Segment
# 1   1     1     2      3      Blue
# 2   2     4     6     10      Green
# 3   3     9    12     21      Blue
# 4   4    16    20     36      Red
# 5   5    25    30     55      Green
# 6   6    36    42     78      Blue
# 7   7    49    56    105      Red
# 8   8    64    72    136      Red
# 9   9    81    90    171      Blue
# 10 10   100   110    210      Green

# %%
y <- c(x$Days)
labels <- c(x$Segment)
pie(y,labels)
# Out:
# plot without title

# %%
x <- c(55, 26, 54, 45)
labels <- c("A","B","C","D")

# %%
pie(x,labels)
# Out:
# plot without title

# %%
x <- c(55, 26, 54, 45)
labels <- c("A","B","C","D")
png(file = "Chart.png")
pie(x,labels)
dev.off()
# Out:
# png
#   2

# %%
x <- c(55, 26, 54, 45)
labels <- c("A","B","C","D")
pie(x,labels, main="Sales")
# Out:
# Plot with title “Sales”

# %%
x <- c(55, 26, 54, 45)
labels <- c("A","B","C","D")
pie(x,labels, main="Sales", col = rainbow(length(x)))
# Out:
# Plot with title “Sales”

# %%
x <- c(55, 26, 54, 45)
labels <- c("A","B","C","D")
pie(x,labels, main="Sales", col = rainbow(length(x)))
legend("topright", c("A","B","C","D"))
# Out:
# Plot with title “Sales”

# %%
x <- c(55, 26, 54, 45)
labels <- c("A","B","C","D")
pie(x, labels, main = "Sales Data",col = rainbow(length(x)))
legend("topright", c("A","B","C","D"), cex = 1.2,   fill = rainbow(length(x)))
# Out:
# Plot with title “Sales Data”

# %%
A<-read.csv("Plot.csv")

# %%
x<- c(A$Days)
y <- c(A$Sales)

# %%
plot(x,y)
# Out:
# plot without title

# %%
barplot(x)
# Out:
# plot without title

# %%
barplot(x,names.arg=y,xlab="Days",ylab="Sakes",col="green",main="Sales vs Days",border="red")
# Out:
# Plot with title “Sales vs Days”

# %%
colors = c("green","orange","brown")
barplot(c(A$Sales), main = "Sales", names.arg = c(A$Days), xlab = "Days", ylab = "Sales", col = colors)
# Out:
# Plot with title “Sales”

# %%
boxplot(c(A$Days), data = c(A$Sales),  xlab = "Days", ylab = "Sales", col = colors)
# Out:
# plot without title

# %%
input <- mtcars[,c('mpg','cyl')]

# %%
input
# Out:
#                     mpg  cyl
# Mazda RX4           21.0 6
# Mazda RX4 Wag       21.0 6
# Datsun 710          22.8 4
# Hornet 4 Drive      21.4 6
# Hornet Sportabout   18.7 8
# Valiant             18.1 6
# Duster 360          14.3 8
# Merc 240D           24.4 4
# Merc 230            22.8 4
# Merc 280            19.2 6
# Merc 280C           17.8 6
# Merc 450SE          16.4 8
# Merc 450SL          17.3 8
# Merc 450SLC         15.2 8
# Cadillac Fleetwood  10.4 8
# Lincoln Continental 10.4 8
# Chrysler Imperial   14.7 8
# Fiat 128            32.4 4
# Honda Civic         30.4 4
# Toyota Corolla      33.9 4
# Toyota Corona       21.5 4
# Dodge Challenger    15.5 8
# AMC Javelin         15.2 8
# Camaro Z28          13.3 8
# Pontiac Firebird    19.2 8
# Fiat X1-9           27.3 4
# Porsche 914-2       26.0 4
# Lotus Europa        30.4 4
# Ford Pantera L      15.8 8
# Ferrari Dino        19.7 6
# Maserati Bora       15.0 8
# Volvo 142E          21.4 4

# %%
boxplot(mpg ~ cyl, data = mtcars, xlab = "Number of Cylinders",   ylab = "Miles Per Gallon", main = "Mileage Data")
# Out:
# Plot with title “Mileage Data”

# %%
boxplot(mpg ~ cyl, data = mtcars, 
   xlab = "Number of Cylinders",
   ylab = "Miles Per Gallon", 
   main = "Mileage Data",
   notch = TRUE, 
   varwidth = TRUE, 
   col = c("green","yellow","purple"),
   names = c("High","Medium","Low")
)
# Out:
# Warning message in (function (z, notch = FALSE, width = NULL, varwidth = FALSE, :
# “some notches went outside hinges ('box'): maybe set notch=FALSE”
# Plot with title “Mileage Data”

# %%
hist(A$Sales,xlab = "Weight",col = "yellow",border = "blue")
# Out:
# Plot with title “Histogram of A$Sales”

# %%
plot(A$Sales,type = "o",col = "red", xlab = "Days", ylab = "Sales",    main = " Sales chart")
# Out:
# Plot with title “ Sales chart”

# %%
plot(A$Sales,type = "p",col = "red", xlab = "Days", ylab = "Sales",    main = " Sales chart")
# Out:
# Plot with title “ Sales chart”

# %%
library(ggplot2)

# %%
plot(A$Days,A$Sales)
# Out:
# plot without title

# %%
x<-read.csv("Plot.csv")
ggplot(data = x, mapping = aes(x = Days, y = Sales))
# Out:
# plot without title

# %%
ggplot(data = x, mapping = aes(x = Days, y = Sales)) +  geom_point()
# Out:
# plot without title

# %%
x<-read.csv("Sample - Superstore.csv")

ggplot(data = x, mapping = aes(x = RowID, y = Sales)) +
    geom_boxplot(alpha = 0) +
    geom_jitter(alpha = 0.3, color = "tomato")
# Out:
# plot without title
